# %% [markdown]
# <a href="https://colab.research.google.com/github/promckkon/MK-DCNN/blob/main/MK-DCNN%20with%200dB%20NOISE%20in%20TRIAX%20Dataset%2026212.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import scipy.io
import seaborn as sns
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %% [markdown]
# Dataset Input

# %%
df=pd.DataFrame(columns=['DE_data','fault']) # upload the dataset on googledrive

for root, dirs, files in os.walk("/content/drive/MyDrive/TRIAX_Dataset", topdown=False):
    for file_name in files:
        path = os.path.join(root, file_name)
        print(path)

        mat = scipy.io.loadmat(path)

        key_name = list(mat.keys())[3]
        DE_data = mat.get(key_name)
        fault = np.full((len(DE_data), 1), file_name[:-4])

        df_temp = pd.DataFrame({'DE_data':np.ravel(DE_data) , 'fault':np.ravel(fault)})

        df = pd.concat([df,df_temp],axis=0)
        print(df['fault'].unique())

df.to_csv('/content/drive/MyDrive/MK-DCNN CWRU/NOISE_10_faults.csv',index=False)
# Out:
# /content/drive/MyDrive/TRIAX_Dataset/07_inner.mat
# ['07_inner']
# /content/drive/MyDrive/TRIAX_Dataset/09_inner.mat
# ['07_inner' '09_inner']
# /content/drive/MyDrive/TRIAX_Dataset/09_outer.mat
# /tmp/ipython-input-526425436.py:16: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df_temp],axis=0)
# ['07_inner' '09_inner' '09_outer']
# /content/drive/MyDrive/TRIAX_Dataset/13_inner.mat
# ['07_inner' '09_inner' '09_outer' '13_inner']
# /content/drive/MyDrive/TRIAX_Dataset/13_outer.mat
# ['07_inner' '09_inner' '09_outer' '13_inner' '13_outer']
# /content/drive/MyDrive/TRIAX_Dataset/17_inner.mat
# ['07_inner' '09_inner' '09_outer' '13_inner' '13_outer' '17_inner']
# /content/drive/MyDrive/TRIAX_Dataset/17_outer.mat
# ['07_inner' '09_inner' '09_outer' '13_inner' '13_outer' '17_inner'
#  '17_outer']
# /content/drive/MyDrive/TRIAX_Dataset/Normal.mat
# ['07_inner' '09_inner' '09_outer' '13_inner' '13_outer' '17_inner'
#  '17_outer' 'Normal']

# %% [markdown]
# # Multi-Kernel Deep 1D-CNN

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.5)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical


# Total target rows
TARGET_ROWS = 1800

# Estimate the total number of samples across all fault types
total_samples = sum(len(df[df['fault'] == f]) for f in df['fault'].unique())

# Calculate suitable window size and stride
num_faults = 9
average_samples_per_fault = total_samples / num_faults
approx_windows_per_fault = TARGET_ROWS / num_faults
stride_ratio = 0.8  # Initial stride/window ratio

win_len = int(average_samples_per_fault / approx_windows_per_fault)
stride = int(win_len * stride_ratio)

X=[]
Y=[]


for k in df['fault'].unique():

    df_temp_2 = df[df['fault']==k]

    for i in np.arange(0,len(df_temp_2)-(win_len),stride):
        temp = df_temp_2.iloc[i:i+win_len,:-1].values
        temp = temp.reshape((1,-1))
        X.append(temp)
        Y.append(df_temp_2.iloc[i+win_len,-1])

X=np.array(X)
X=X.reshape((X.shape[0],-1,1))
#X = np.repeat(X, 3, axis=3) # To repeat into 3 chanel format


Y=np.array(Y)
encoder= LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
OHE_Y = to_categorical(encoded_Y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,OHE_Y,test_size=0.3,shuffle=True)

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten, Conv1D, MaxPooling1D, concatenate
from tensorflow.keras import backend as K

# --- Custom Physics-Informed Loss Function ---
def custom_loss(y_true, y_pred):
    # Standard categorical crossentropy
    loss = K.categorical_crossentropy(y_true, y_pred)

    # Physics-Informed Term: penalize rapid class probability changes
    # Ensure y_pred is at least 2D for slicing
    if K.ndim(y_pred) < 2:
        y_pred = K.expand_dims(y_pred, axis=-1)

    # Ensure y_pred has more than one class dimension to compute diff
    if K.int_shape(y_pred)[-1] > 1:
        diff = y_pred[:, 1:] - y_pred[:, :-1]
        squared_diff = tf.square(diff)
        physics_term = tf.reduce_mean(squared_diff)
    else:
        physics_term = 0.0 # No physics term if only one class


    # Total loss = classification loss + regularization term
    total_loss = loss + 0.01 * physics_term  # 0.01 is tunable

    return total_loss

# --- Model Definition ---
# no_classes = len(df['fault'].unique()) # Original line that caused 10 classes
no_classes = len(encoder.classes_) # Use the encoder to get the correct number of classes
print(f"Number of output classes (no_classes): {no_classes}") # Add print statement to verify

input_shape = (X.shape[1], X.shape[2])  # Example: (784, 1)

# Head 1
inputs1 = Input(shape=input_shape)
conv1 = Conv1D(filters=64, kernel_size=200, activation='relu')(inputs1)
drop1 = Dropout(0.3)(conv1)
pool1 = MaxPooling1D(pool_size=10)(drop1)
flat1 = Flatten()(pool1)

# Head 2
inputs2 = Input(shape=input_shape)
conv2 = Conv1D(filters=64, kernel_size=100, activation='relu')(inputs2)
drop2 = Dropout(0.3)(conv2)
pool2 = MaxPooling1D(pool_size=10)(drop2)
flat2 = Flatten()(pool2)

# Head 3
inputs3 = Input(shape=input_shape)
conv3 = Conv1D(filters=64, kernel_size=50, activation='relu')(inputs3)
drop3 = Dropout(0.3)(conv3)
pool3 = MaxPooling1D(pool_size=10)(drop3)
flat3 = Flatten()(pool3)

# Merge all feature paths
merged = concatenate([flat1, flat2, flat3])

# Fully connected interpretation
dense1 = Dense(256, activation='relu')(merged)
outputs = Dense(no_classes, activation='softmax')(dense1)

# Build and compile model with custom loss
cnn_model = Model(inputs=[inputs1, inputs2, inputs3], outputs=outputs)
cnn_model.compile(optimizer='adam', loss=custom_loss, metrics=['accuracy'])

# Model summary
cnn_model.summary()
# Out:
# Number of output classes (no_classes): 8
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_18      │ (None, 614, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_19      │ (None, 614, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_20      │ (None, 614, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, 415, 64)   │     12,864 │ input_layer_18[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_19 (Conv1D)  │ (None, 515, 64)   │      6,464 │ input_layer_19[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_20 (Conv1D)  │ (None, 565, 64)   │      3,264 │ input_layer_20[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 415, 64)   │          0 │ conv1d_18[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 515, 64)   │          0 │ conv1d_19[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 565, 64)   │          0 │ conv1d_20[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_18    │ (None, 41, 64)    │          0 │ dropout_18[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_19    │ (None, 51, 64)    │          0 │ dropout_19[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_20    │ (None, 56, 64)    │          0 │ dropout_20[0][0]  │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_18          │ (None, 2624)      │          0 │ max_pooling1d_18… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_19          │ (None, 3264)      │          0 │ max_pooling1d_19… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_20          │ (None, 3584)      │          0 │ max_pooling1d_20… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 9472)      │          0 │ flatten_18[0][0], │
# │ (Concatenate)       │                   │            │ flatten_19[0][0], │
# │                     │                   │            │ flatten_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 256)       │  2,425,088 │ concatenate_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 8)         │      2,056 │ dense_12[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,449,736 (9.35 MB)
#  Trainable params: 2,449,736 (9.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
batch_size =300
epochs = 60
history = cnn_model.fit([X_train,X_train,X_train], y_train, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=([X_test,X_test,X_test],y_test),shuffle=True)
# Out:
# Epoch 1/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.1176 - loss: 3.6869 - val_accuracy: 0.1187 - val_loss: 2.4444
# Epoch 2/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.1272 - loss: 2.2734 - val_accuracy: 0.1380 - val_loss: 1.9886
# Epoch 3/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.1168 - loss: 2.0102 - val_accuracy: 0.2552 - val_loss: 1.8064
# Epoch 4/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.2633 - loss: 1.7915 - val_accuracy: 0.3472 - val_loss: 1.6998
# Epoch 5/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4030 - loss: 1.6378 - val_accuracy: 0.4955 - val_loss: 1.5309
# Epoch 6/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5006 - loss: 1.4448 - val_accuracy: 0.4896 - val_loss: 1.3487
# Epoch 7/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4855 - loss: 1.3081 - val_accuracy: 0.5772 - val_loss: 1.2126
# Epoch 8/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5915 - loss: 1.1356 - val_accuracy: 0.6454 - val_loss: 1.1003
# Epoch 9/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6788 - loss: 0.9860 - val_accuracy: 0.6246 - val_loss: 0.9838
# Epoch 10/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6963 - loss: 0.8473 - val_accuracy: 0.7671 - val_loss: 0.8605
# Epoch 11/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8272 - loss: 0.7294 - val_accuracy: 0.7804 - val_loss: 0.8222
# Epoch 12/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8607 - loss: 0.6188 - val_accuracy: 0.8264 - val_loss: 0.7038
# Epoch 13/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8894 - loss: 0.5011 - val_accuracy: 0.8398 - val_loss: 0.5950
# Epoch 14/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8853 - loss: 0.4059 - val_accuracy: 0.8457 - val_loss: 0.5677
# Epoch 15/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8996 - loss: 0.3436 - val_accuracy: 0.8472 - val_loss: 0.5303
# Epoch 16/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9156 - loss: 0.2936 - val_accuracy: 0.8769 - val_loss: 0.4451
# Epoch 17/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9395 - loss: 0.2307 - val_accuracy: 0.8427 - val_loss: 0.4980
# Epoch 18/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9476 - loss: 0.2217 - val_accuracy: 0.8932 - val_loss: 0.3958
# Epoch 19/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9522 - loss: 0.1837 - val_accuracy: 0.9199 - val_loss: 0.3436
# Epoch 20/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9628 - loss: 0.1536 - val_accuracy: 0.8947 - val_loss: 0.3865
# Epoch 21/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9545 - loss: 0.1589 - val_accuracy: 0.9243 - val_loss: 0.3132
# Epoch 22/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9630 - loss: 0.1276 - val_accuracy: 0.8813 - val_loss: 0.3731
# Epoch 23/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9754 - loss: 0.1147 - val_accuracy: 0.9125 - val_loss: 0.3275
# Epoch 24/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9805 - loss: 0.1052 - val_accuracy: 0.9451 - val_loss: 0.2473
# Epoch 25/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9883 - loss: 0.0857 - val_accuracy: 0.9065 - val_loss: 0.3107
# Epoch 26/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9908 - loss: 0.0687 - val_accuracy: 0.9407 - val_loss: 0.2456
# Epoch 27/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9922 - loss: 0.0592 - val_accuracy: 0.9436 - val_loss: 0.2401
# Epoch 28/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9954 - loss: 0.0527 - val_accuracy: 0.9332 - val_loss: 0.2550
# Epoch 29/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9925 - loss: 0.0501 - val_accuracy: 0.9451 - val_loss: 0.2307
# Epoch 30/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9990 - loss: 0.0401 - val_accuracy: 0.9407 - val_loss: 0.2392
# Epoch 31/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9970 - loss: 0.0391 - val_accuracy: 0.9421 - val_loss: 0.2227
# Epoch 32/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9990 - loss: 0.0330 - val_accuracy: 0.9421 - val_loss: 0.2373
# Epoch 33/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9989 - loss: 0.0341 - val_accuracy: 0.9451 - val_loss: 0.2129
# Epoch 34/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9994 - loss: 0.0297 - val_accuracy: 0.9421 - val_loss: 0.2393
# Epoch 35/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9985 - loss: 0.0273 - val_accuracy: 0.9481 - val_loss: 0.2112
# Epoch 36/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9994 - loss: 0.0249 - val_accuracy: 0.9481 - val_loss: 0.2168
# Epoch 37/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9992 - loss: 0.0235 - val_accuracy: 0.9496 - val_loss: 0.2090
# Epoch 38/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9994 - loss: 0.0218 - val_accuracy: 0.9436 - val_loss: 0.2144
# Epoch 39/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9987 - loss: 0.0209 - val_accuracy: 0.9481 - val_loss: 0.2084
# Epoch 40/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9992 - loss: 0.0186 - val_accuracy: 0.9496 - val_loss: 0.2052
# Epoch 41/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9997 - loss: 0.0162 - val_accuracy: 0.9466 - val_loss: 0.2137
# Epoch 42/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9998 - loss: 0.0165 - val_accuracy: 0.9481 - val_loss: 0.2060
# Epoch 43/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.9466 - val_loss: 0.2026
# Epoch 44/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0158 - val_accuracy: 0.9481 - val_loss: 0.2061
# Epoch 45/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.9466 - val_loss: 0.2034
# Epoch 46/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.9496 - val_loss: 0.2028
# Epoch 47/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.9496 - val_loss: 0.2007
# Epoch 48/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.9496 - val_loss: 0.1938
# Epoch 49/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 0.9466 - val_loss: 0.2104
# Epoch 50/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.9496 - val_loss: 0.1982
# Epoch 51/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.9481 - val_loss: 0.1898
# Epoch 52/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.9466 - val_loss: 0.2056
# Epoch 53/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0099 - val_accuracy: 0.9481 - val_loss: 0.1948
# Epoch 54/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.9481 - val_loss: 0.2008
# Epoch 55/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.9466 - val_loss: 0.2053
# Epoch 56/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.9496 - val_loss: 0.1926
# Epoch 57/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.9481 - val_loss: 0.1972
# Epoch 58/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9466 - val_loss: 0.1991
# Epoch 59/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0082 - val_accuracy: 0.9496 - val_loss: 0.1943
# Epoch 60/60
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9466 - val_loss: 0.1975

# %%
import matplotlib.pyplot as plt
import numpy as np

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

step = 2
x = np.arange(0, len(acc), step)

plt.figure(figsize=(5,4))

plt.plot(x, np.array(acc)[::step],
         linestyle="--", marker="o", markersize=4,
         label="accuracy")

plt.plot(x, np.array(val_acc)[::step],
         linestyle="--", marker="o", markersize=4,
         label="val_accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.yticks(np.arange(0, 1.01, 0.1))


plt.xlim(-2, len(acc)+2)


plt.ylim(0, 1.05)

plt.legend(loc="lower right")
plt.grid(True)
plt.tight_layout()


plt.savefig("learning_curve.png",
            dpi=600,
            bbox_inches='tight',
            pad_inches=0.1)

plt.show()

# %%
def inv_Transform_result(y_pred):
    y_pred = y_pred.argmax(axis=1)
    y_pred = encoder.inverse_transform(y_pred)
    return y_pred



y_pred=cnn_model.predict([X_test,X_test,X_test])


Y_pred=inv_Transform_result(y_pred)
Y_test = inv_Transform_result(y_test)




from sklearn.metrics import confusion_matrix


plt.figure(figsize=(10,10))
cm = confusion_matrix(Y_test, Y_pred,normalize='true')
f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step
